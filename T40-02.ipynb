# %% [markdown]
# # Aula 01 - Introdução ao Python para Ciência de Dados
#
# O nome desse tipo de edição de texto é __Markdown__ (https://www.markdownguide.org/).

# %% [markdown]
# __Objetivo__: Apresentar os conceitos iniciais da linguagem Python abordando os operadores aritméticos, relacionais e lógicos, além de comandos de saída e entra (leitura do teclado).

# %% [markdown]
# __Variável__: é um objeto localizado na memória da máquina, capaz de armazenar dados para representar um valor ou uma função (expressão) através de um __nome__.
#
# Em Python, temos três tipo:
# *   Numérico
# *   Texto ou *string*
# *   Lógico ou *booleano*
#
# **Observações Importantes**
# * Em Python não há a necessidade especificar que tipo uma variável deve ser, pois a própria linguagem reconhece o tipo de acordo com o valor atribuído.
# * Python é Case Sensitive, ou seja, diferencia letras maiúsculas de minúsculas.
# * Para definirmos o nome de variáveis, temos que iniciar utilizando um caractere que esteja no intervalo de `a` à `z` ou `A` à `Z` e de `0` a `9`. A única exceção a esta regra é o caractere underscore "`_`".
# * Podemos utilizar números, desde que seja o segundo caractere da sequência.
# * Também é desejável e prudente que os nomes tenham relação com o seu significado.

# %%
# Isso é um comentário

# Variáveis numéricas:
# int: número inteiro
# float: ponto flutuante (real)

# %%
x = 10 # int
y = 7.3 # float

# %%
# mostrando valores através do comando print()
print(x)
print(y)
# Out:
# 10
# 7.3

# %%
# outra forma de mostar valores
print(x, y) # cada parâmetro deve ser separado por vírgula
# Out:
# 10 7.3

# %%
print(x, "\n", y)
# Out:
# 10
#  7.3

# %%
# Descobrir o TIPO de dados de uma variável
print(type(x), x)
print(type(y), y)
# Out:
# <class 'int'> 10
# <class 'float'> 7.3

# %%
# melhorando a apresentação
print('O valor de x é:', x, type(x))
# Out:
# O valor de x é: 10 <class 'int'>

# %%
# Codificar uma saída desta forma
# O valor de "x" é 10 e o seu tipo é <class 'int'> 10
# Obs: O str() converte qualquer valor numérico em "string"
print('O valor de x é ' + str(x) + ' e o seu tipo é ' + str(type(x)))
# Out:
# O valor de x é 10 e o seu tipo é <class 'int'>

# %%
# Variáveis string - devem estar envolvidas por aspas, podendo ser simples ou dupla
curso = 'Ciências da Computação'
disciplina = "Ciência de Dados"
ano = '2022'

print(curso, type(curso))
print(disciplina, type(disciplina))
print(ano, type(ano))
# Out:
# Ciências da Computação <class 'str'>
# Ciência de Dados <class 'str'>
# 2022 <class 'str'>

# %%
# outro exemplo
nome = 'Edson Melo tem'
idade = 51
complemento = 'anos'
print(nome, idade, complemento)
# Out:
# Edson Melo tem 51 anos

# %%
# formatação mais chique
print("O valor da variável 'y' é %.02f" %y)
# Out:
# O valor da variável 'y' é 7.30

# %% [markdown]
# # Operadores Aritméticos
#
# | Operação      | Operador |
# |---------------|:--------:|
# | Adição        |     +    |
# | Subtração     |     -    |
# | Multiplicação |     *    |
# | Divisão       |     /    |
# | Exponenciação |    **    |
# | Parte Inteira |    //    |
# | Módulo        |     %    |

# %%
a = 5
b = 7
print("+", a+b)
print("-", a-b)
print("*", a*b)
print("/", a/b)
print("**", a**b)
print("//", a//b)
print("%", a%b)
# Out:
# + 12
# - -2
# * 35
# / 0.7142857142857143
# ** 78125
# // 0
# % 5

# %%
# Exercício
# Utilizando variáveis (uma para cada número), faça um script para realizar o seguinte cálculo:
# result = 10 + 20 -30 + (45*3)/8**2
# Tempo: 7 minutos
v1 = 10
v2 = 20
v3 = 30
v4 = 45
v5 = 3
v6 = 8
v7 = 2
print( v1 + v2 - v3 + (v4 * v5) / v6 ** v7 )
# Out:
# 2.109375

# %% [markdown]
# # Operadores Relacionais
# | Descrição        | Operador |
# |------------------|:--------:|
# | Maior que        |     >    |
# | Menor que        |     <    |
# | Igual a          |    ==    |
# | Maior ou igual a |    >=    |
# | Menor ou igual a |    <=    |
# | Diferente        |    !=    |

# %%
print(x > y)
print(x < y)
# Out:
# True
# False

# %% [markdown]
# ### **Operadores Lógicos**
#
# Esses operadores permitem unir 2 expressões ligando-as com os conectivos lógicos matemáticos e são:
#
# | Operador Lógico 	| Função    	| Prioridade 	|
# |-----------------	|-----------	|:----------:	|
# | NOT             	| Negação   	|      1     	|
# | AND             	| Conjunção 	|      2     	|
# | OR              	| Disjunção 	|      3     	|

# %%
a = 1
b = 5
c = 2
d = 6
print((a >1) and (c < 3))
print((b <d) or (a > 1))
print(not (c > d) and (d == b))
# Out:
# False
# True
# False

# %% [markdown]
# # Leitura de Teclado
# A função utilizada para isso é o input()

# %%
entrada = input('Digite um nome:')
print('Olá', entrada)
# Out:
# Digite um nome:Edson
# Olá Edson

# %%
# Atenção: para manipular leitura de números é preciso converter
entrada = input('Digite um valor:')
print('Olá', entrada, type(entrada))
# Out:
# Digite um valor:Edson
# Olá Edson <class 'str'>

# %% [markdown]
# ### **Conversões de tipos**
# * Absoluto abs(x)
# * Conveter para Inteiro: int(x)
# * Converter para Real: float(x)
# * Converter para String: str(valor)

# %%
valor1 = int(input('Digite um valor:'))
valor2 = input('Digite outro valor:')
print(type(valor1))
print(type(valor2))
print(valor1 * int(valor2))
# Out:
# Digite um valor:10
# Digite outro valor:2
# <class 'int'>
# <class 'str'>
# 20

# %% [markdown]
# # Exercícios de Fixação
# 1) Implemente um programa que escreve na tela a frase "Meu primeiro programa em Python!!!".
#
# 2) Você foi contratado por uma escola pra fazer o sistema de boletim dos alunos. Como primeiro passo, escreva um programa que produza a seguinte saída (Não é necessário manter o alinhamento):
#
# | Aluno(a)        	|  Nota 	|
# |-----------------	|------:	|
# | Ana Maria       	|  9.00 	|
# | José Carlos     	|  7.20 	|
# | Júlio Martins   	|  8.00 	|
# | Ubiratan Santos 	| 10.00 	|
#
# 3) Calcule o **delta** da equação a seguir, realizando a entrada dos valores de (a, b e c) pelo teclado.
#
# Exemplo: $x^2 + 12x - 13 = 0$ (a=1, b=12 e c=-13).
#
# $\Delta = b^2 - 4 * a * c$

# %%
import math
print(math.sqrt(64))
# Out:
# 8.0

# %%
#1
print("Meu primeiro programa em Python!!!")
# Out:
# Meu primeiro programa em Python!!!

# %%
# 2.
print("Aluno", "Nota")
print("Ana Maria %.2f" %9.0)
print("José Carlos %.2f" %7.2)
print("Júlio Martins %.2f" %8.0)
print("Ubiratan Santos %.2f" %10.0)
# Out:
# Aluno Nota
# Ana Maria 9.00
# José Carlos 7.20
# Júlio Martins 8.00
# Ubiratan Santos 10.00

# %%
# Outra forma de resolução do ex. 2. Realizando o alinhamento à direita dos números
print(f"Ana Maria \t{9.0:>5,.02f}")
print(f"José Carlos \t{7.2:>5,.02f}")
print(f"Júlio Martins \t{8:>5,.02f}")
print(f"Ubiratan Santos {10.0:>5,.02f}")
# Out:
# Ana Maria 	 9.00
# José Carlos 	 7.20
# Júlio Martins 	 8.00
# Ubiratan Santos 10.00

# %%
#3
a = 1
b = 12
c = -13
delta = (b ** 2) - 4 * a * c
print('O resultado é:', delta)
# Out:
# O resultado é: 196
