# %% [markdown]
# # Estatísticas com Pandas
#
# * Média
# * Mediana
# * Moda
# * Desvio Padrão(Std)

# %%
import pandas as pd

# %%
corona = pd.read_csv('http://emsapi.esy.es/datasets/covid_19_data.csv', index_col=0)

# %%
corona.head()
# Out:
#     ObservationDate Province/State  Country/Region      Last Update  \
# SNo
# 1        01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 2        01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 3        01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 4        01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 5        01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#      Confirmed  Deaths  Recovered
# SNo
# 1          1.0     0.0        0.0
# 2         14.0     0.0        0.0
# 3          6.0     0.0        0.0
# 4          1.0     0.0        0.0
# 5          0.0     0.0        0.0

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98252 entries, 1 to 98252
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ObservationDate  98252 non-null  object
#  1   Province/State   67099 non-null  object
#  2   Country/Region   98252 non-null  object
#  3   Last Update      98252 non-null  object
#  4   Confirmed        98252 non-null  float64
#  5   Deaths           98252 non-null  float64
#  6   Recovered        98252 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 6.0+ MB

# %%
corona.shape
# Out:
# (98252, 7)

# %%
# Estátistica Básica com Pandas
# .describe
corona.describe()
# Out:
#            Confirmed        Deaths     Recovered
# count   98252.000000  98252.000000  9.825200e+04
# mean    15442.707232    692.502310  8.392821e+03
# std     46813.313272   2712.094164  4.751247e+04
# min         0.000000      0.000000  0.000000e+00
# 25%       181.000000      2.000000  2.000000e+00
# 50%      1622.000000     31.000000  2.870000e+02
# 75%      8301.250000    264.000000  2.850000e+03
# max    801422.000000  42072.000000  2.140614e+06

# %%
# Outro exemplo
notas = pd.read_csv('http://emsapi.esy.es/datasets/notas_alunos.csv', index_col=0)
notas.describe()
# Out:
#            Nota1      Nota2      Nota3      Nota4      Nota5
# count  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    4.737200   5.760000   4.480000   5.520000   5.620000
# std     2.992104   3.034227   2.936331   3.382066   3.069867
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     2.000000   3.000000   2.000000   3.000000   3.000000
# 50%     5.500000   6.500000   4.500000   5.500000   6.000000
# 75%     7.000000   8.000000   7.000000   8.000000   8.000000
# max     9.080000  10.000000   9.000000  10.000000  10.000000

# %% [markdown]
# # Métodos Estátisticos do Pandas
# * ``mean()``: média
# * ``sum()``: soma
# * ``median()``: mediana
# * ``std()``: Desvio Padrão (Desv.Pad) ou Standard Deviation (std)
# * ``min()``: mínimo
# * ``max()``: máximo

# %%
print('Média: ', corona['Confirmed'].mean())
print('Mediana: ', corona['Confirmed'].median())
print('Desvio Padrão: ', corona['Confirmed'].std())
print('Mínimo: ', corona['Confirmed'].min())
print('Máximo: ', corona['Confirmed'].max())
print('Soma: ', corona['Confirmed'].sum())
# Out:
# Média:  15442.70723242275
# Mediana:  1622.0
# Desvio Padrão:  46813.31327228468
# Mínimo:  0.0
# Máximo:  801422.0
# Soma:  1517276871.0

# %%
# Agregar as colunas Confirmed e Deaths em uma nova coluna chamada 'Confirmed + Deaths'
corona['Confirmed + Deaths'] = corona['Confirmed'] + corona['Deaths']
corona.head()
# Out:
#     ObservationDate Province/State  Country/Region      Last Update  \
# SNo
# 1        01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 2        01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 3        01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 4        01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 5        01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#      Confirmed  Deaths  Recovered  Confirmed + Deaths
# SNo
# 1          1.0     0.0        0.0                 1.0
# 2         14.0     0.0        0.0                14.0
# 3          6.0     0.0        0.0                 6.0
# 4          1.0     0.0        0.0                 1.0
# 5          0.0     0.0        0.0                 0.0

# %%
# corona.Confirmed.mean()
# corona['Confirmed'].mean
# corona.Confirmed.describe().mean()

# %%
# Elaborar um algoritmo que mostre as estatísticas das colunas de um DataFrame
# utilizando os métodos de forma individual
# 1 - O que deve-se analisar?
# R: Deve-se analisar quais são numéricas, pois estatísticas são somente sobre 
# esse tipo de dado
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98252 entries, 1 to 98252
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ObservationDate     98252 non-null  object
#  1   Province/State      67099 non-null  object
#  2   Country/Region      98252 non-null  object
#  3   Last Update         98252 non-null  object
#  4   Confirmed           98252 non-null  float64
#  5   Deaths              98252 non-null  float64
#  6   Recovered           98252 non-null  float64
#  7   Confirmed + Deaths  98252 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 6.7+ MB

# %%
# 2 - Qual o melhor método para implementar essa resolução?
# R: Utilizar o laço de repetição (for)

# %%
# 3 - Montar o algoritmo
# Vamos resolver com um subset

colunas = ['Confirmed', 'Deaths', 'Recovered', 'Confirmed + Deaths']
for coluna in colunas:
  print('coluna:', coluna)
  print('\tMédia: ', round(corona[coluna].mean(), 2))
  print()
# Out:
# coluna: Confirmed
# 	Média:  15442.71
#
# coluna: Deaths
# 	Média:  692.5
#
# coluna: Recovered
# 	Média:  8392.82
#
# coluna: Confirmed + Deaths
# 	Média:  16135.21

# %%
# Usando o mesmo algoritmo acima, implememtar uma alteração que não necessite 
# informar quais são as colunas numéricas, ou seja,
# identificar automaticamnete as colunmas.
colunas = (corona.select_dtypes(include=['float64']))
for coluna in colunas:
  print('coluna:', coluna)
  print('\tMédia: ', round(corona[coluna].mean(), 2))
  print()
# Out:
# coluna: Confirmed
# 	Média:  15442.71
#
# coluna: Deaths
# 	Média:  692.5
#
# coluna: Recovered
# 	Média:  8392.82
#
# coluna: Confirmed + Deaths
# 	Média:  16135.21

# %% [markdown]
# # Funções Oython
# * def nome da funcao(parametros)
#
# <corpo da função>

# %%
# Função somar()
# Sem retorno
def somar_sem_retorno(num1, num2):
  print(num1+num2)

# %%
somar(10, 20)
# Out:
# 30

# %%
# Função somar
# Com retorno
def somar_com_retorno(num1, num2):
  return (num1+num2)

# %%
resultado = somar(10, 20)

# %%
resultado
# Out:
# 30

# %%
# Função com retorno composto
# Permite retornar mais de um valor separado por vírgula
# Isso é muito bom quando precisamos realizar processos independentes com valores
def soma_multiplica(x, y):
  return (x+y), (x*y)

# %%
soma_multiplica(10, 20)
# Out:
# (30, 200)

# %%
# O Python permite uma declaração com múltiplas variáveis
soma, multiplicacao = soma_multiplica(2, 3)

# %%
print('Soma:', soma)
print('Multiplicação:', multiplicacao)
# Out:
# Soma: 5
# Multiplicação: 6

# %%
# Função com múltiplos valores de entrada
def somar_varios(valores): # o parâmetro é uma lista
  return sum(valores), len(valores)

# %%
somar_varios([1,2,3,4,5])
# Out:
# (15, 5)
